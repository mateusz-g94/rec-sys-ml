# %%
# !pip install -q tensorflow-recommenders
# !pip install -q --upgrade tensorflow-datasets
# !pip install -q scann
# Out:
#      |████████████████████████████████| 85 kB 2.3 MB/s
#      |████████████████████████████████| 4.0 MB 5.2 MB/s
#      |████████████████████████████████| 10.6 MB 969 kB/s

# %%
import os
import tempfile

# %matplotlib inline
import matplotlib.pyplot as plt

import numpy as np
import tensorflow as tf
import tensorflow_datasets as tfds

import tensorflow_recommenders as tfrs

plt.style.use('seaborn-whitegrid')

# %%
ratings = tfds.load("movielens/100k-ratings", split="train")
movies = tfds.load("movielens/100k-movies", split="train")

ratings = ratings.map(lambda x: {
    "movie_title": x["movie_title"],
    "user_id": x["user_id"]
})
movies = movies.map(lambda x: x["movie_title"])
# Out:
# Downloading and preparing dataset 4.70 MiB (download: 4.70 MiB, generated: 32.41 MiB, total: 37.10 MiB) to /root/tensorflow_datasets/movielens/100k-ratings/0.1.0...
# Dl Completed...: 0 url [00:00, ? url/s]
# Dl Size...: 0 MiB [00:00, ? MiB/s]
# Extraction completed...: 0 file [00:00, ? file/s]
# Generating splits...:   0%|          | 0/1 [00:00<?, ? splits/s]
# Generating train examples...:   0%|          | 0/100000 [00:00<?, ? examples/s]
# Shuffling movielens-train.tfrecord...:   0%|          | 0/100000 [00:00<?, ? examples/s]
# Dataset movielens downloaded and prepared to /root/tensorflow_datasets/movielens/100k-ratings/0.1.0. Subsequent calls will reuse this data.
# Downloading and preparing dataset 4.70 MiB (download: 4.70 MiB, generated: 150.35 KiB, total: 4.84 MiB) to /root/tensorflow_datasets/movielens/100k-movies/0.1.0...
# Dl Completed...: 0 url [00:00, ? url/s]
# Dl Size...: 0 MiB [00:00, ? MiB/s]
# Extraction completed...: 0 file [00:00, ? file/s]
# Generating splits...:   0%|          | 0/1 [00:00<?, ? splits/s]
# Generating train examples...:   0%|          | 0/1682 [00:00<?, ? examples/s]
# Shuffling movielens-train.tfrecord...:   0%|          | 0/1682 [00:00<?, ? examples/s]
# Dataset movielens downloaded and prepared to /root/tensorflow_datasets/movielens/100k-movies/0.1.0. Subsequent calls will reuse this data.

# %%
unique_movie_titles = np.unique(np.concatenate(list(movies.batch(1000))))
unique_user_ids = np.unique(np.concatenate(list(ratings.batch(1_000).map(lambda x: x["user_id"]))))

# %% [markdown]
# #### Query Model

# %%
class UserModel(tf.keras.Model):

  def __init__(self):
    super().__init__()

    self.user_embedding = tf.keras.Sequential([
        tf.keras.layers.StringLookup(
            vocabulary=unique_user_ids, mask_token=None),
        tf.keras.layers.Embedding(len(unique_user_ids) + 1, 32),
    ])
    
  def call(self, inputs):
    # Take the input dictionary, pass it through each input layer,
    # and concatenate the result.
    return tf.concat([
        self.user_embedding(inputs)
    ], axis=1)

# %%
class QueryModel(tf.keras.Model):
  """Model for encoding user queries."""

  def __init__(self, layer_sizes):
    """Model for encoding user queries.

    Args:
      layer_sizes:
        A list of integers where the i-th entry represents the number of units
        the i-th layer contains.
    """
    super().__init__()

    # We first use the user model for generating embeddings.
    self.embedding_model = UserModel()

    # Then construct the layers.
    self.dense_layers = tf.keras.Sequential()

    # Use the ReLU activation for all but the last layer.
    for layer_size in layer_sizes[:-1]:
      self.dense_layers.add(tf.keras.layers.Dense(layer_size, activation="relu"))

    # No activation for the last layer.
    for layer_size in layer_sizes[-1:]:
      self.dense_layers.add(tf.keras.layers.Dense(layer_size))

  def call(self, inputs):
    feature_embedding = self.embedding_model(inputs)
    return self.dense_layers(feature_embedding)

# %% [markdown]
# ### Candidate Model

# %%
class MovieModel(tf.keras.Model):

  def __init__(self):
    super().__init__()

    max_tokens = 10_000

    self.title_embedding = tf.keras.Sequential([
      tf.keras.layers.StringLookup(
          vocabulary=unique_movie_titles,mask_token=None),
      tf.keras.layers.Embedding(len(unique_movie_titles) + 1, 25)
    ])

    self.title_vectorizer = tf.keras.layers.TextVectorization(
        max_tokens=max_tokens)

    self.title_text_embedding = tf.keras.Sequential([
      self.title_vectorizer,
      tf.keras.layers.Embedding(max_tokens, 7, mask_zero=True),
      tf.keras.layers.GlobalAveragePooling1D(),
    ])

    self.title_vectorizer.adapt(movies)

  def call(self, titles):
    return tf.concat([
        self.title_embedding(titles),
        self.title_text_embedding(titles),
    ], axis=1)

# %%
class CandidateModel(tf.keras.Model):
  """Model for encoding movies."""

  def __init__(self, layer_sizes):
    """Model for encoding movies.

    Args:
      layer_sizes:
        A list of integers where the i-th entry represents the number of units
        the i-th layer contains.
    """
    super().__init__()

    self.embedding_model = MovieModel()

    # Then construct the layers.
    self.dense_layers = tf.keras.Sequential()

    # Use the ReLU activation for all but the last layer.
    for layer_size in layer_sizes[:-1]:
      self.dense_layers.add(tf.keras.layers.Dense(layer_size, activation="relu"))

    # No activation for the last layer.
    for layer_size in layer_sizes[-1:]:
      self.dense_layers.add(tf.keras.layers.Dense(layer_size))

  def call(self, inputs):
    feature_embedding = self.embedding_model(inputs)
    return self.dense_layers(feature_embedding)

# %% [markdown]
# ### Combined Model

# %%
class MovielensModel(tfrs.models.Model):

  def __init__(self, layer_sizes):
    super().__init__()
    self.query_model = QueryModel(layer_sizes)
    self.candidate_model = CandidateModel(layer_sizes)
    self.task = tfrs.tasks.Retrieval(
        metrics=tfrs.metrics.FactorizedTopK(
            candidates=movies.batch(128).map(self.candidate_model),
        ),
    )

  def compute_loss(self, features, training=False):
    # We only pass the user id and timestamp features into the query model. This
    # is to ensure that the training inputs would have the same keys as the
    # query inputs. Otherwise the discrepancy in input structure would cause an
    # error when loading the query model after saving it.
    query_embeddings = self.query_model(features["user_id"])
    movie_embeddings = self.candidate_model(features["movie_title"])

    return self.task(
        query_embeddings, movie_embeddings, compute_metrics=not training)

# %% [markdown]
# ### Training

# %%
tf.random.set_seed(42)
shuffled = ratings.shuffle(100_000, seed=42, reshuffle_each_iteration=False)

train = shuffled.take(80_000)
test = shuffled.skip(80_000).take(20_000)

cached_train = train.shuffle(100_000).batch(2048)
cached_test = test.batch(4096).cache()

# %%
num_epochs = 300

model = MovielensModel([64, 32])
model.compile(optimizer=tf.keras.optimizers.Adam())

two_layer_history = model.fit(
    cached_train,
    validation_data=cached_test,
    validation_freq=5,
    epochs=num_epochs,
    verbose=1)

accuracy = two_layer_history.history["val_factorized_top_k/top_100_categorical_accuracy"][-1]
print(f"Top-100 accuracy: {accuracy:.2f}.")
# Out:
# Epoch 1/300
# 40/40 [==============================] - 8s 84ms/step - factorized_top_k/top_1_categorical_accuracy: 0.0000e+00 - factorized_top_k/top_5_categorical_accuracy: 0.0000e+00 - factorized_top_k/top_10_categorical_accuracy: 0.0000e+00 - factorized_top_k/top_50_categorical_accuracy: 0.0000e+00 - factorized_top_k/top_100_categorical_accuracy: 0.0000e+00 - loss: 14883.6739 - regularization_loss: 0.0000e+00 - total_loss: 14883.6739
# Epoch 2/300
# 40/40 [==============================] - 6s 84ms/step - factorized_top_k/top_1_categorical_accuracy: 0.0000e+00 - factorized_top_k/top_5_categorical_accuracy: 0.0000e+00 - factorized_top_k/top_10_categorical_accuracy: 0.0000e+00 - factorized_top_k/top_50_categorical_accuracy: 0.0000e+00 - factorized_top_k/top_100_categorical_accuracy: 0.0000e+00 - loss: 14756.7483 - regularization_loss: 0.0000e+00 - total_loss: 14756.7483
# Epoch 3/300
# 40/40 [==============================] - 6s 85ms/step - factorized_top_k/top_1_categorical_accuracy: 0.0000e+00 - factorized_top_k/top_5_categorical_accuracy: 0.0000e+00 - factorized_top_k/top_10_categorical_accuracy: 0.0000e+00 - factorized_top_k/top_50_categorical_accuracy: 0.0000e+00 - factorized_top_k/top_100_categorical_accuracy: 0.0000e+00 - loss: 14516.0621 - regularization_loss: 0.0000e+00 - total_loss: 14516.0621
# Epoch 4/300
# 40/40 [==============================] - 6s 84ms/step - factorized_top_k/top_1_categorical_accuracy: 0.0000e+00 - factorized_top_k/top_5_categorical_accuracy: 0.0000e+00 - factorized_top_k/top_10_categorical_accuracy: 0.0000e+00 - factorized_top_k/top_50_categorical_accuracy: 0.0000e+00 - factorized_top_k/top_100_categorical_accuracy: 0.0000e+00 - loss: 14417.9988 - regularization_loss: 0.0000e+00 - total_loss: 14417.9988
# Epoch 5/300
# 40/40 [==============================] - 15s 307ms/step - factorized_top_k/top_1_categorical_accuracy: 0.0000e+00 - factorized_top_k/top_5_categorical_accuracy: 0.0000e+00 - factorized_top_k/top_10_categorical_accuracy: 0.0000e+00 - factorized_top_k/top_50_categorical_accuracy: 0.0000e+00 - factorized_top_k/top_100_categorical_accuracy: 0.0000e+00 - loss: 14268.6149 - regularization_loss: 0.0000e+00 - total_loss: 14268.6149 - val_factorized_top_k/top_1_categorical_accuracy: 4.5000e-04 - val_factorized_top_k/top_5_categorical_accuracy: 0.0044 - val_factorized_top_k/top_10_categorical_accuracy: 0.0100 - val_factorized_top_k/top_50_categorical_accuracy: 0.0662 - val_factorized_top_k/top_100_categorical_accuracy: 0.1414 - val_loss: 28564.8848 - val_regularization_loss: 0.0000e+00 - val_total_loss: 28564.8848
# Epoch 6/300
# 40/40 [==============================] - 6s 82ms/step - factorized_top_k/top_1_categorical_accuracy: 0.0000e+00 - factorized_top_k/top_5_categorical_accuracy: 0.0000e+00 - factorized_top_k/top_10_categorical_accuracy: 0.0000e+00 - factorized_top_k/top_50_categorical_accuracy: 0.0000e+00 - factorized_top_k/top_100_categorical_accuracy: 0.0000e+00 - loss: 14210.9653 - regularization_loss: 0.0000e+00 - total_loss: 14210.9653
# Epoch 7/300
# 40/40 [==============================] - 6s 81ms/step - factorized_top_k/top_1_categorical_accuracy: 0.0000e+00 - factorized_top_k/top_5_categorical_accuracy: 0.0000e+00 - factorized_top_k/top_10_categorical_accuracy: 0.0000e+00 - factorized_top_k/top_50_categorical_accuracy: 0.0000e+00 - factorized_top_k/top_100_categorical_accuracy: 0.0000e+00 - loss: 14184.2002 - regularization_loss: 0.0000e+00 - total_loss: 14184.2002
# Epoch 8/300
# 40/40 [==============================] - 6s 81ms/step - factorized_top_k/top_1_categorical_accuracy: 0.0000e+00 - factorized_top_k/top_5_categorical_accuracy: 0.0000e+00 - factorized_top_k/top_10_categorical_accuracy: 0.0000e+00 - factorized_top_k/top_50_categorical_accuracy: 0.0000e+00 - factorized_top_k/top_100_categorical_accuracy: 0.0000e+00 - loss: 14157.0990 - regularization_loss: 0.0000e+00 - total_loss: 14157.0990
# Epoch 9/300
# 40/40 [==============================] - 6s 81ms/step - factorized_top_k/top_1_categorical_accuracy: 0.0000e+00 - factorized_top_k/top_5_categorical_accuracy: 0.0000e+00 - factorized_top_k/top_10_categorical_accuracy: 0.0000e+00 - factorized_top_k/top_50_categorical_accuracy: 0.0000e+00 - factorized_top_k/top_100_categorical_accuracy: 0.0000e+00 - loss: 14126.8369 - regularization_loss: 0.0000e+00 - total_loss: 14126.8369
# Epoch 10/300
# 40/40 [==============================] - 11s 205ms/step - factorized_top_k/top_1_categorical_accuracy: 0.0000e+00 - factorized_top_k/top_5_categorical_accuracy: 0.0000e+00 - factorized_top_k/top_10_categorical_accuracy: 0.0000e+00 - factorized_top_k/top_50_categorical_accuracy: 0.0000e+00 - factorized_top_k/top_100_categorical_accuracy: 0.0000e+00 - loss: 14103.9634 - regularization_loss: 0.0000e+00 - total_loss: 14103.9634 - val_factorized_top_k/top_1_categorical_accuracy: 5.0000e-04 - val_factorized_top_k/top_5_categorical_accuracy: 0.0041 - val_factorized_top_k/top_10_categorical_accuracy: 0.0109 - val_factorized_top_k/top_50_categorical_accuracy: 0.0693 - val_factorized_top_k/top_100_categorical_accuracy: 0.1472 - val_loss: 28386.6387 - val_regularization_loss: 0.0000e+00 - val_total_loss: 28386.6387
# Epoch 11/300
# 40/40 [==============================] - 6s 82ms/step - factorized_top_k/top_1_categorical_accuracy: 0.0000e+00 - factorized_top_k/top_5_categorical_accuracy: 0.0000e+00 - factorized_top_k/top_10_categorical_accuracy: 0.0000e+00 - factorized_top_k/top_50_categorical_accuracy: 0.0000e+00 - factorized_top_k/top_100_categorical_accuracy: 0.0000e+00 - loss: 14086.7073 - regularization_loss: 0.0000e+00 - total_loss: 14086.7073
# Epoch 12/300
# 40/40 [==============================] - 6s 81ms/step - factorized_top_k/top_1_categorical_accuracy: 0.0000e+00 - factorized_top_k/top_5_categorical_accuracy: 0.0000e+00 - factorized_top_k/top_10_categorical_accuracy: 0.0000e+00 - factorized_top_k/top_50_categorical_accuracy: 0.0000e+00 - factorized_top_k/top_100_categorical_accuracy: 0.0000e+00 - loss: 14072.8381 - regularization_loss: 0.0000e+00 - total_loss: 14072.8381
# Epoch 13/300
# 40/40 [==============================] - 6s 82ms/step - factorized_top_k/top_1_categorical_accuracy: 0.0000e+00 - factorized_top_k/top_5_categorical_accuracy: 0.0000e+00 - factorized_top_k/top_10_categorical_accuracy: 0.0000e+00 - factorized_top_k/top_50_categorical_accuracy: 0.0000e+00 - factorized_top_k/top_100_categorical_accuracy: 0.0000e+00 - loss: 14054.8751 - regularization_loss: 0.0000e+00 - total_loss: 14054.8751
# Epoch 14/300
# 40/40 [==============================] - 6s 82ms/step - factorized_top_k/top_1_categorical_accuracy: 0.0000e+00 - factorized_top_k/top_5_categorical_accuracy: 0.0000e+00 - factorized_top_k/top_10_categorical_accuracy: 0.0000e+00 - factorized_top_k/top_50_categorical_accuracy: 0.0000e+00 - factorized_top_k/top_100_categorical_accuracy: 0.0000e+00 - loss: 14023.7249 - regularization_loss: 0.0000e+00 - total_loss: 14023.7249
# Epoch 15/300
# 40/40 [==============================] - 11s 204ms/step - factorized_top_k/top_1_categorical_accuracy: 0.0000e+00 - factorized_top_k/top_5_categorical_accuracy: 0.0000e+00 - factorized_top_k/top_10_categorical_accuracy: 0.0000e+00 - factorized_top_k/top_50_categorical_accuracy: 0.0000e+00 - factorized_top_k/top_100_categorical_accuracy: 0.0000e+00 - loss: 13985.7278 - regularization_loss: 0.0000e+00 - total_loss: 13985.7278 - val_factorized_top_k/top_1_categorical_accuracy: 4.0000e-04 - val_factorized_top_k/top_5_categorical_accuracy: 0.0060 - val_factorized_top_k/top_10_categorical_accuracy: 0.0138 - val_factorized_top_k/top_50_categorical_accuracy: 0.0817 - val_factorized_top_k/top_100_categorical_accuracy: 0.1638 - val_loss: 28306.0586 - val_regularization_loss: 0.0000e+00 - val_total_loss: 28306.0586
# Epoch 16/300
# 40/40 [==============================] - 6s 84ms/step - factorized_top_k/top_1_categorical_accuracy: 0.0000e+00 - factorized_top_k/top_5_categorical_accuracy: 0.0000e+00 - factorized_top_k/top_10_categorical_accuracy: 0.0000e+00 - factorized_top_k/top_50_categorical_accuracy: 0.0000e+00 - factorized_top_k/top_100_categorical_accuracy: 0.0000e+00 - loss: 13958.2252 - regularization_loss: 0.0000e+00 - total_loss: 13958.2252
# Epoch 17/300
# 40/40 [==============================] - 6s 83ms/step - factorized_top_k/top_1_categorical_accuracy: 0.0000e+00 - factorized_top_k/top_5_categorical_accuracy: 0.0000e+00 - factorized_top_k/top_10_categorical_accuracy: 0.0000e+00 - factorized_top_k/top_50_categorical_accuracy: 0.0000e+00 - factorized_top_k/top_100_categorical_accuracy: 0.0000e+00 - loss: 13939.6844 - regularization_loss: 0.0000e+00 - total_loss: 13939.6844
# Epoch 18/300
# 40/40 [==============================] - 6s 83ms/step - factorized_top_k/top_1_categorical_accuracy: 0.0000e+00 - factorized_top_k/top_5_categorical_accuracy: 0.0000e+00 - factorized_top_k/top_10_categorical_accuracy: 0.0000e+00 - factorized_top_k/top_50_categorical_accuracy: 0.0000e+00 - factorized_top_k/top_100_categorical_accuracy: 0.0000e+00 - loss: 13928.4933 - regularization_loss: 0.0000e+00 - total_loss: 13928.4933
# Epoch 19/300
# 40/40 [==============================] - 6s 84ms/step - factorized_top_k/top_1_categorical_accuracy: 0.0000e+00 - factorized_top_k/top_5_categorical_accuracy: 0.0000e+00 - factorized_top_k/top_10_categorical_accuracy: 0.0000e+00 - factorized_top_k/top_50_categorical_accuracy: 0.0000e+00 - factorized_top_k/top_100_categorical_accuracy: 0.0000e+00 - loss: 13919.7806 - regularization_loss: 0.0000e+00 - total_loss: 13919.7806
# Epoch 20/300
# 40/40 [==============================] - 11s 208ms/step - factorized_top_k/top_1_categorical_accuracy: 0.0000e+00 - factorized_top_k/top_5_categorical_accuracy: 0.0000e+00 - factorized_top_k/top_10_categorical_accuracy: 0.0000e+00 - factorized_top_k/top_50_categorical_accuracy: 0.0000e+00 - factorized_top_k/top_100_categorical_accuracy: 0.0000e+00 - loss: 13913.0478 - regularization_loss: 0.0000e+00 - total_loss: 13913.0478 - val_factorized_top_k/top_1_categorical_accuracy: 7.5000e-04 - val_factorized_top_k/top_5_categorical_accuracy: 0.0069 - val_factorized_top_k/top_10_categorical_accuracy: 0.0158 - val_factorized_top_k/top_50_categorical_accuracy: 0.0944 - val_factorized_top_k/top_100_categorical_accuracy: 0.1855 - val_loss: 28255.4258 - val_regularization_loss: 0.0000e+00 - val_total_loss: 28255.4258
# Epoch 21/300
# 40/40 [==============================] - 6s 86ms/step - factorized_top_k/top_1_categorical_accuracy: 0.0000e+00 - factorized_top_k/top_5_categorical_accuracy: 0.0000e+00 - factorized_top_k/top_10_categorical_accuracy: 0.0000e+00 - factorized_top_k/top_50_categorical_accuracy: 0.0000e+00 - factorized_top_k/top_100_categorical_accuracy: 0.0000e+00 - loss: 13907.9791 - regularization_loss: 0.0000e+00 - total_loss: 13907.9791
# Epoch 22/300
# 40/40 [==============================] - 6s 87ms/step - factorized_top_k/top_1_categorical_accuracy: 0.0000e+00 - factorized_top_k/top_5_categorical_accuracy: 0.0000e+00 - factorized_top_k/top_10_categorical_accuracy: 0.0000e+00 - factorized_top_k/top_50_categorical_accuracy: 0.0000e+00 - factorized_top_k/top_100_categorical_accuracy: 0.0000e+00 - loss: 13903.2677 - regularization_loss: 0.0000e+00 - total_loss: 13903.2677
# Epoch 23/300
# 40/40 [==============================] - 6s 88ms/step - factorized_top_k/top_1_categorical_accuracy: 0.0000e+00 - factorized_top_k/top_5_categorical_accuracy: 0.0000e+00 - factorized_top_k/top_10_categorical_accuracy: 0.0000e+00 - factorized_top_k/top_50_categorical_accuracy: 0.0000e+00 - factorized_top_k/top_100_categorical_accuracy: 0.0000e+00 - loss: 13898.3546 - regularization_loss: 0.0000e+00 - total_loss: 13898.3546
# Epoch 24/300
# 40/40 [==============================] - 6s 91ms/step - factorized_top_k/top_1_categorical_accuracy: 0.0000e+00 - factorized_top_k/top_5_categorical_accuracy: 0.0000e+00 - factorized_top_k/top_10_categorical_accuracy: 0.0000e+00 - factorized_top_k/top_50_categorical_accuracy: 0.0000e+00 - factorized_top_k/top_100_categorical_accuracy: 0.0000e+00 - loss: 13893.3025 - regularization_loss: 0.0000e+00 - total_loss: 13893.3025
# Epoch 25/300
# 40/40 [==============================] - 11s 224ms/step - factorized_top_k/top_1_categorical_accuracy: 0.0000e+00 - factorized_top_k/top_5_categorical_accuracy: 0.0000e+00 - factorized_top_k/top_10_categorical_accuracy: 0.0000e+00 - factorized_top_k/top_50_categorical_accuracy: 0.0000e+00 - factorized_top_k/top_100_categorical_accuracy: 0.0000e+00 - loss: 13891.5166 - regularization_loss: 0.0000e+00 - total_loss: 13891.5166 - val_factorized_top_k/top_1_categorical_accuracy: 5.5000e-04 - val_factorized_top_k/top_5_categorical_accuracy: 0.0063 - val_factorized_top_k/top_10_categorical_accuracy: 0.0147 - val_factorized_top_k/top_50_categorical_accuracy: 0.0926 - val_factorized_top_k/top_100_categorical_accuracy: 0.1876 - val_loss: 28256.0195 - val_regularization_loss: 0.0000e+00 - val_total_loss: 28256.0195
# Epoch 26/300
# 40/40 [==============================] - 6s 86ms/step - factorized_top_k/top_1_categorical_accuracy: 0.0000e+00 - factorized_top_k/top_5_categorical_accuracy: 0.0000e+00 - factorized_top_k/top_10_categorical_accuracy: 0.0000e+00 - factorized_top_k/top_50_categorical_accuracy: 0.0000e+00 - factorized_top_k/top_100_categorical_accuracy: 0.0000e+00 - loss: 13886.8343 - regularization_loss: 0.0000e+00 - total_loss: 13886.8343
# Epoch 27/300
# 40/40 [==============================] - 6s 87ms/step - factorized_top_k/top_1_categorical_accuracy: 0.0000e+00 - factorized_top_k/top_5_categorical_accuracy: 0.0000e+00 - factorized_top_k/top_10_categorical_accuracy: 0.0000e+00 - factorized_top_k/top_50_categorical_accuracy: 0.0000e+00 - factorized_top_k/top_100_categorical_accuracy: 0.0000e+00 - loss: 13882.7350 - regularization_loss: 0.0000e+00 - total_loss: 13882.7350
# Epoch 28/300
# 40/40 [==============================] - 6s 86ms/step - factorized_top_k/top_1_categorical_accuracy: 0.0000e+00 - factorized_top_k/top_5_categorical_accuracy: 0.0000e+00 - factorized_top_k/top_10_categorical_accuracy: 0.0000e+00 - factorized_top_k/top_50_categorical_accuracy: 0.0000e+00 - factorized_top_k/top_100_categorical_accuracy: 0.0000e+00 - loss: 13878.8569 - regularization_loss: 0.0000e+00 - total_loss: 13878.8569
# Epoch 29/300
# 40/40 [==============================] - 6s 87ms/step - factorized_top_k/top_1_categorical_accuracy: 0.0000e+00 - factorized_top_k/top_5_categorical_accuracy: 0.0000e+00 - factorized_top_k/top_10_categorical_accuracy: 0.0000e+00 - factorized_top_k/top_50_categorical_accuracy: 0.0000e+00 - factorized_top_k/top_100_categorical_accuracy: 0.0000e+00 - loss: 13872.4824 - regularization_loss: 0.0000e+00 - total_loss: 13872.4824
# Epoch 30/300
# 40/40 [==============================] - 12s 230ms/step - factorized_top_k/top_1_categorical_accuracy: 0.0000e+00 - factorized_top_k/top_5_categorical_accuracy: 0.0000e+00 - factorized_top_k/top_10_categorical_accuracy: 0.0000e+00 - factorized_top_k/top_50_categorical_accuracy: 0.0000e+00 - factorized_top_k/top_100_categorical_accuracy: 0.0000e+00 - loss: 13866.4905 - regularization_loss: 0.0000e+00 - total_loss: 13866.4905 - val_factorized_top_k/top_1_categorical_accuracy: 6.5000e-04 - val_factorized_top_k/top_5_categorical_accuracy: 0.0064 - val_factorized_top_k/top_10_categorical_accuracy: 0.0150 - val_factorized_top_k/top_50_categorical_accuracy: 0.0957 - val_factorized_top_k/top_100_categorical_accuracy: 0.1953 - val_loss: 28253.9902 - val_regularization_loss: 0.0000e+00 - val_total_loss: 28253.9902
# Epoch 31/300
# 40/40 [==============================] - 6s 90ms/step - factorized_top_k/top_1_categorical_accuracy: 0.0000e+00 - factorized_top_k/top_5_categorical_accuracy: 0.0000e+00 - factorized_top_k/top_10_categorical_accuracy: 0.0000e+00 - factorized_top_k/top_50_categorical_accuracy: 0.0000e+00 - factorized_top_k/top_100_categorical_accuracy: 0.0000e+00 - loss: 13858.1034 - regularization_loss: 0.0000e+00 - total_loss: 13858.1034
# Epoch 32/300
# 40/40 [==============================] - 8s 124ms/step - factorized_top_k/top_1_categorical_accuracy: 0.0000e+00 - factorized_top_k/top_5_categorical_accuracy: 0.0000e+00 - factorized_top_k/top_10_categorical_accuracy: 0.0000e+00 - factorized_top_k/top_50_categorical_accuracy: 0.0000e+00 - factorized_top_k/top_100_categorical_accuracy: 0.0000e+00 - loss: 13845.4772 - regularization_loss: 0.0000e+00 - total_loss: 13845.4772
# Epoch 33/300
# 40/40 [==============================] - 6s 92ms/step - factorized_top_k/top_1_categorical_accuracy: 0.0000e+00 - factorized_top_k/top_5_categorical_accuracy: 0.0000e+00 - factorized_top_k/top_10_categorical_accuracy: 0.0000e+00 - factorized_top_k/top_50_categorical_accuracy: 0.0000e+00 - factorized_top_k/top_100_categorical_accuracy: 0.0000e+00 - loss: 13832.1868 - regularization_loss: 0.0000e+00 - total_loss: 13832.1868
# Epoch 34/300
# 40/40 [==============================] - 6s 91ms/step - factorized_top_k/top_1_categorical_accuracy: 0.0000e+00 - factorized_top_k/top_5_categorical_accuracy: 0.0000e+00 - factorized_top_k/top_10_categorical_accuracy: 0.0000e+00 - factorized_top_k/top_50_categorical_accuracy: 0.0000e+00 - factorized_top_k/top_100_categorical_accuracy: 0.0000e+00 - loss: 13817.2404 - regularization_loss: 0.0000e+00 - total_loss: 13817.2404
# Epoch 35/300
# 40/40 [==============================] - 11s 217ms/step - factorized_top_k/top_1_categorical_accuracy: 0.0000e+00 - factorized_top_k/top_5_categorical_accuracy: 0.0000e+00 - factorized_top_k/top_10_categorical_accuracy: 0.0000e+00 - factorized_top_k/top_50_categorical_accuracy: 0.0000e+00 - factorized_top_k/top_100_categorical_accuracy: 0.0000e+00 - loss: 13800.7972 - regularization_loss: 0.0000e+00 - total_loss: 13800.7972 - val_factorized_top_k/top_1_categorical_accuracy: 4.5000e-04 - val_factorized_top_k/top_5_categorical_accuracy: 0.0064 - val_factorized_top_k/top_10_categorical_accuracy: 0.0153 - val_factorized_top_k/top_50_categorical_accuracy: 0.0994 - val_factorized_top_k/top_100_categorical_accuracy: 0.2038 - val_loss: 28232.1055 - val_regularization_loss: 0.0000e+00 - val_total_loss: 28232.1055
# Epoch 36/300
# 40/40 [==============================] - 6s 92ms/step - factorized_top_k/top_1_categorical_accuracy: 0.0000e+00 - factorized_top_k/top_5_categorical_accuracy: 0.0000e+00 - factorized_top_k/top_10_categorical_accuracy: 0.0000e+00 - factorized_top_k/top_50_categorical_accuracy: 0.0000e+00 - factorized_top_k/top_100_categorical_accuracy: 0.0000e+00 - loss: 13787.2111 - regularization_loss: 0.0000e+00 - total_loss: 13787.2111
# Epoch 37/300
# 40/40 [==============================] - 6s 90ms/step - factorized_top_k/top_1_categorical_accuracy: 0.0000e+00 - factorized_top_k/top_5_categorical_accuracy: 0.0000e+00 - factorized_top_k/top_10_categorical_accuracy: 0.0000e+00 - factorized_top_k/top_50_categorical_accuracy: 0.0000e+00 - factorized_top_k/top_100_categorical_accuracy: 0.0000e+00 - loss: 13773.9549 - regularization_loss: 0.0000e+00 - total_loss: 13773.9549
# Epoch 38/300
# 40/40 [==============================] - 6s 91ms/step - factorized_top_k/top_1_categorical_accuracy: 0.0000e+00 - factorized_top_k/top_5_categorical_accuracy: 0.0000e+00 - factorized_top_k/top_10_categorical_accuracy: 0.0000e+00 - factorized_top_k/top_50_categorical_accuracy: 0.0000e+00 - factorized_top_k/top_100_categorical_accuracy: 0.0000e+00 - loss: 13763.0952 - regularization_loss: 0.0000e+00 - total_loss: 13763.0952
# Epoch 39/300
# 40/40 [==============================] - 6s 90ms/step - factorized_top_k/top_1_categorical_accuracy: 0.0000e+00 - factorized_top_k/top_5_categorical_accuracy: 0.0000e+00 - factorized_top_k/top_10_categorical_accuracy: 0.0000e+00 - factorized_top_k/top_50_categorical_accuracy: 0.0000e+00 - factorized_top_k/top_100_categorical_accuracy: 0.0000e+00 - loss: 13752.1935 - regularization_loss: 0.0000e+00 - total_loss: 13752.1935
# Epoch 40/300
# 40/40 [==============================] - 12s 225ms/step - factorized_top_k/top_1_categorical_accuracy: 0.0000e+00 - factorized_top_k/top_5_categorical_accuracy: 0.0000e+00 - factorized_top_k/top_10_categorical_accuracy: 0.0000e+00 - factorized_top_k/top_50_categorical_accuracy: 0.0000e+00 - factorized_top_k/top_100_categorical_accuracy: 0.0000e+00 - loss: 13745.2410 - regularization_loss: 0.0000e+00 - total_loss: 13745.2410 - val_factorized_top_k/top_1_categorical_accuracy: 7.5000e-04 - val_factorized_top_k/top_5_categorical_accuracy: 0.0071 - val_factorized_top_k/top_10_categorical_accuracy: 0.0165 - val_factorized_top_k/top_50_categorical_accuracy: 0.1020 - val_factorized_top_k/top_100_categorical_accuracy: 0.2049 - val_loss: 28190.7363 - val_regularization_loss: 0.0000e+00 - val_total_loss: 28190.7363
# Epoch 41/300
# 40/40 [==============================] - 6s 89ms/step - factorized_top_k/top_1_categorical_accuracy: 0.0000e+00 - factorized_top_k/top_5_categorical_accuracy: 0.0000e+00 - factorized_top_k/top_10_categorical_accuracy: 0.0000e+00 - factorized_top_k/top_50_categorical_accuracy: 0.0000e+00 - factorized_top_k/top_100_categorical_accuracy: 0.0000e+00 - loss: 13737.1833 - regularization_loss: 0.0000e+00 - total_loss: 13737.1833
# Epoch 42/300
# 40/40 [==============================] - 6s 88ms/step - factorized_top_k/top_1_categorical_accuracy: 0.0000e+00 - factorized_top_k/top_5_categorical_accuracy: 0.0000e+00 - factorized_top_k/top_10_categorical_accuracy: 0.0000e+00 - factorized_top_k/top_50_categorical_accuracy: 0.0000e+00 - factorized_top_k/top_100_categorical_accuracy: 0.0000e+00 - loss: 13729.6118 - regularization_loss: 0.0000e+00 - total_loss: 13729.6118
# Epoch 43/300
# 40/40 [==============================] - 6s 88ms/step - factorized_top_k/top_1_categorical_accuracy: 0.0000e+00 - factorized_top_k/top_5_categorical_accuracy: 0.0000e+00 - factorized_top_k/top_10_categorical_accuracy: 0.0000e+00 - factorized_top_k/top_50_categorical_accuracy: 0.0000e+00 - factorized_top_k/top_100_categorical_accuracy: 0.0000e+00 - loss: 13723.1855 - regularization_loss: 0.0000e+00 - total_loss: 13723.1855
# Epoch 44/300
# 40/40 [==============================] - 6s 87ms/step - factorized_top_k/top_1_categorical_accuracy: 0.0000e+00 - factorized_top_k/top_5_categorical_accuracy: 0.0000e+00 - factorized_top_k/top_10_categorical_accuracy: 0.0000e+00 - factorized_top_k/top_50_categorical_accuracy: 0.0000e+00 - factorized_top_k/top_100_categorical_accuracy: 0.0000e+00 - loss: 13717.6583 - regularization_loss: 0.0000e+00 - total_loss: 13717.6583
# Epoch 45/300
# 40/40 [==============================] - 12s 229ms/step - factorized_top_k/top_1_categorical_accuracy: 0.0000e+00 - factorized_top_k/top_5_categorical_accuracy: 0.0000e+00 - factorized_top_k/top_10_categorical_accuracy: 0.0000e+00 - factorized_top_k/top_50_categorical_accuracy: 0.0000e+00 - factorized_top_k/top_100_categorical_accuracy: 0.0000e+00 - loss: 13711.8108 - regularization_loss: 0.0000e+00 - total_loss: 13711.8108 - val_factorized_top_k/top_1_categorical_accuracy: 4.5000e-04 - val_factorized_top_k/top_5_categorical_accuracy: 0.0058 - val_factorized_top_k/top_10_categorical_accuracy: 0.0144 - val_factorized_top_k/top_50_categorical_accuracy: 0.0997 - val_factorized_top_k/top_100_categorical_accuracy: 0.2037 - val_loss: 28199.4492 - val_regularization_loss: 0.0000e+00 - val_total_loss: 28199.4492
# Epoch 46/300
# 40/40 [==============================] - 6s 90ms/step - factorized_top_k/top_1_categorical_accuracy: 0.0000e+00 - factorized_top_k/top_5_categorical_accuracy: 0.0000e+00 - factorized_top_k/top_10_categorical_accuracy: 0.0000e+00 - factorized_top_k/top_50_categorical_accuracy: 0.0000e+00 - factorized_top_k/top_100_categorical_accuracy: 0.0000e+00 - loss: 13707.6077 - regularization_loss: 0.0000e+00 - total_loss: 13707.6077
# Epoch 47/300
# 40/40 [==============================] - 6s 91ms/step - factorized_top_k/top_1_categorical_accuracy: 0.0000e+00 - factorized_top_k/top_5_categorical_accuracy: 0.0000e+00 - factorized_top_k/top_10_categorical_accuracy: 0.0000e+00 - factorized_top_k/top_50_categorical_accuracy: 0.0000e+00 - factorized_top_k/top_100_categorical_accuracy: 0.0000e+00 - loss: 13702.3746 - regularization_loss: 0.0000e+00 - total_loss: 13702.3746
# Epoch 48/300
# 40/40 [==============================] - 7s 94ms/step - factorized_top_k/top_1_categorical_accuracy: 0.0000e+00 - factorized_top_k/top_5_categorical_accuracy: 0.0000e+00 - factorized_top_k/top_10_categorical_accuracy: 0.0000e+00 - factorized_top_k/top_50_categorical_accuracy: 0.0000e+00 - factorized_top_k/top_100_categorical_accuracy: 0.0000e+00 - loss: 13697.0719 - regularization_loss: 0.0000e+00 - total_loss: 13697.0719
# Epoch 49/300
# 40/40 [==============================] - 6s 93ms/step - factorized_top_k/top_1_categorical_accuracy: 0.0000e+00 - factorized_top_k/top_5_categorical_accuracy: 0.0000e+00 - factorized_top_k/top_10_categorical_accuracy: 0.0000e+00 - factorized_top_k/top_50_categorical_accuracy: 0.0000e+00 - factorized_top_k/top_100_categorical_accuracy: 0.0000e+00 - loss: 13693.3649 - regularization_loss: 0.0000e+00 - total_loss: 13693.3649
# Epoch 50/300
# 40/40 [==============================] - 12s 241ms/step - factorized_top_k/top_1_categorical_accuracy: 0.0000e+00 - factorized_top_k/top_5_categorical_accuracy: 0.0000e+00 - factorized_top_k/top_10_categorical_accuracy: 0.0000e+00 - factorized_top_k/top_50_categorical_accuracy: 0.0000e+00 - factorized_top_k/top_100_categorical_accuracy: 0.0000e+00 - loss: 13689.6136 - regularization_loss: 0.0000e+00 - total_loss: 13689.6136 - val_factorized_top_k/top_1_categorical_accuracy: 7.0000e-04 - val_factorized_top_k/top_5_categorical_accuracy: 0.0060 - val_factorized_top_k/top_10_categorical_accuracy: 0.0132 - val_factorized_top_k/top_50_categorical_accuracy: 0.0996 - val_factorized_top_k/top_100_categorical_accuracy: 0.2022 - val_loss: 28202.8203 - val_regularization_loss: 0.0000e+00 - val_total_loss: 28202.8203
# Epoch 51/300
# 40/40 [==============================] - 7s 94ms/step - factorized_top_k/top_1_categorical_accuracy: 0.0000e+00 - factorized_top_k/top_5_categorical_accuracy: 0.0000e+00 - factorized_top_k/top_10_categorical_accuracy: 0.0000e+00 - factorized_top_k/top_50_categorical_accuracy: 0.0000e+00 - factorized_top_k/top_100_categorical_accuracy: 0.0000e+00 - loss: 13684.8190 - regularization_loss: 0.0000e+00 - total_loss: 13684.8190
# Epoch 52/300
# 40/40 [==============================] - 7s 95ms/step - factorized_top_k/top_1_categorical_accuracy: 0.0000e+00 - factorized_top_k/top_5_categorical_accuracy: 0.0000e+00 - factorized_top_k/top_10_categorical_accuracy: 0.0000e+00 - factorized_top_k/top_50_categorical_accuracy: 0.0000e+00 - factorized_top_k/top_100_categorical_accuracy: 0.0000e+00 - loss: 13679.8268 - regularization_loss: 0.0000e+00 - total_loss: 13679.8268
# Epoch 53/300
# 40/40 [==============================] - 7s 93ms/step - factorized_top_k/top_1_categorical_accuracy: 0.0000e+00 - factorized_top_k/top_5_categorical_accuracy: 0.0000e+00 - factorized_top_k/top_10_categorical_accuracy: 0.0000e+00 - factorized_top_k/top_50_categorical_accuracy: 0.0000e+00 - factorized_top_k/top_100_categorical_accuracy: 0.0000e+00 - loss: 13675.6925 - regularization_loss: 0.0000e+00 - total_loss: 13675.6925
# Epoch 54/300
# 40/40 [==============================] - 7s 93ms/step - factorized_top_k/top_1_categorical_accuracy: 0.0000e+00 - factorized_top_k/top_5_categorical_accuracy: 0.0000e+00 - factorized_top_k/top_10_categorical_accuracy: 0.0000e+00 - factorized_top_k/top_50_categorical_accuracy: 0.0000e+00 - factorized_top_k/top_100_categorical_accuracy: 0.0000e+00 - loss: 13672.7639 - regularization_loss: 0.0000e+00 - total_loss: 13672.7639
# Epoch 55/300
# 40/40 [==============================] - 12s 229ms/step - factorized_top_k/top_1_categorical_accuracy: 0.0000e+00 - factorized_top_k/top_5_categorical_accuracy: 0.0000e+00 - factorized_top_k/top_10_categorical_accuracy: 0.0000e+00 - factorized_top_k/top_50_categorical_accuracy: 0.0000e+00 - factorized_top_k/top_100_categorical_accuracy: 0.0000e+00 - loss: 13668.3158 - regularization_loss: 0.0000e+00 - total_loss: 13668.3158 - val_factorized_top_k/top_1_categorical_accuracy: 3.5000e-04 - val_factorized_top_k/top_5_categorical_accuracy: 0.0058 - val_factorized_top_k/top_10_categorical_accuracy: 0.0148 - val_factorized_top_k/top_50_categorical_accuracy: 0.1055 - val_factorized_top_k/top_100_categorical_accuracy: 0.2141 - val_loss: 28213.5039 - val_regularization_loss: 0.0000e+00 - val_total_loss: 28213.5039
# Epoch 56/300
# 40/40 [==============================] - 6s 88ms/step - factorized_top_k/top_1_categorical_accuracy: 0.0000e+00 - factorized_top_k/top_5_categorical_accuracy: 0.0000e+00 - factorized_top_k/top_10_categorical_accuracy: 0.0000e+00 - factorized_top_k/top_50_categorical_accuracy: 0.0000e+00 - factorized_top_k/top_100_categorical_accuracy: 0.0000e+00 - loss: 13664.1344 - regularization_loss: 0.0000e+00 - total_loss: 13664.1344
# Epoch 57/300
# 40/40 [==============================] - 6s 91ms/step - factorized_top_k/top_1_categorical_accuracy: 0.0000e+00 - factorized_top_k/top_5_categorical_accuracy: 0.0000e+00 - factorized_top_k/top_10_categorical_accuracy: 0.0000e+00 - factorized_top_k/top_50_categorical_accuracy: 0.0000e+00 - factorized_top_k/top_100_categorical_accuracy: 0.0000e+00 - loss: 13659.0978 - regularization_loss: 0.0000e+00 - total_loss: 13659.0978
# Epoch 58/300
# 40/40 [==============================] - 6s 90ms/step - factorized_top_k/top_1_categorical_accuracy: 0.0000e+00 - factorized_top_k/top_5_categorical_accuracy: 0.0000e+00 - factorized_top_k/top_10_categorical_accuracy: 0.0000e+00 - factorized_top_k/top_50_categorical_accuracy: 0.0000e+00 - factorized_top_k/top_100_categorical_accuracy: 0.0000e+00 - loss: 13653.3362 - regularization_loss: 0.0000e+00 - total_loss: 13653.3362
# Epoch 59/300
# 40/40 [==============================] - 6s 90ms/step - factorized_top_k/top_1_categorical_accuracy: 0.0000e+00 - factorized_top_k/top_5_categorical_accuracy: 0.0000e+00 - factorized_top_k/top_10_categorical_accuracy: 0.0000e+00 - factorized_top_k/top_50_categorical_accuracy: 0.0000e+00 - factorized_top_k/top_100_categorical_accuracy: 0.0000e+00 - loss: 13648.4342 - regularization_loss: 0.0000e+00 - total_loss: 13648.4342
# Epoch 60/300
# 40/40 [==============================] - 12s 225ms/step - factorized_top_k/top_1_categorical_accuracy: 0.0000e+00 - factorized_top_k/top_5_categorical_accuracy: 0.0000e+00 - factorized_top_k/top_10_categorical_accuracy: 0.0000e+00 - factorized_top_k/top_50_categorical_accuracy: 0.0000e+00 - factorized_top_k/top_100_categorical_accuracy: 0.0000e+00 - loss: 13640.9824 - regularization_loss: 0.0000e+00 - total_loss: 13640.9824 - val_factorized_top_k/top_1_categorical_accuracy: 3.0000e-04 - val_factorized_top_k/top_5_categorical_accuracy: 0.0048 - val_factorized_top_k/top_10_categorical_accuracy: 0.0138 - val_factorized_top_k/top_50_categorical_accuracy: 0.1041 - val_factorized_top_k/top_100_categorical_accuracy: 0.2146 - val_loss: 28210.4902 - val_regularization_loss: 0.0000e+00 - val_total_loss: 28210.4902
# Epoch 61/300
# 40/40 [==============================] - 6s 89ms/step - factorized_top_k/top_1_categorical_accuracy: 0.0000e+00 - factorized_top_k/top_5_categorical_accuracy: 0.0000e+00 - factorized_top_k/top_10_categorical_accuracy: 0.0000e+00 - factorized_top_k/top_50_categorical_accuracy: 0.0000e+00 - factorized_top_k/top_100_categorical_accuracy: 0.0000e+00 - loss: 13635.3106 - regularization_loss: 0.0000e+00 - total_loss: 13635.3106
# Epoch 62/300
# 40/40 [==============================] - 6s 88ms/step - factorized_top_k/top_1_categorical_accuracy: 0.0000e+00 - factorized_top_k/top_5_categorical_accuracy: 0.0000e+00 - factorized_top_k/top_10_categorical_accuracy: 0.0000e+00 - factorized_top_k/top_50_categorical_accuracy: 0.0000e+00 - factorized_top_k/top_100_categorical_accuracy: 0.0000e+00 - loss: 13629.6390 - regularization_loss: 0.0000e+00 - total_loss: 13629.6390
# Epoch 63/300
# 40/40 [==============================] - 6s 88ms/step - factorized_top_k/top_1_categorical_accuracy: 0.0000e+00 - factorized_top_k/top_5_categorical_accuracy: 0.0000e+00 - factorized_top_k/top_10_categorical_accuracy: 0.0000e+00 - factorized_top_k/top_50_categorical_accuracy: 0.0000e+00 - factorized_top_k/top_100_categorical_accuracy: 0.0000e+00 - loss: 13623.4987 - regularization_loss: 0.0000e+00 - total_loss: 13623.4987
# Epoch 64/300
# 40/40 [==============================] - 6s 89ms/step - factorized_top_k/top_1_categorical_accuracy: 0.0000e+00 - factorized_top_k/top_5_categorical_accuracy: 0.0000e+00 - factorized_top_k/top_10_categorical_accuracy: 0.0000e+00 - factorized_top_k/top_50_categorical_accuracy: 0.0000e+00 - factorized_top_k/top_100_categorical_accuracy: 0.0000e+00 - loss: 13617.5430 - regularization_loss: 0.0000e+00 - total_loss: 13617.5430
# Epoch 65/300
# 40/40 [==============================] - 12s 231ms/step - factorized_top_k/top_1_categorical_accuracy: 0.0000e+00 - factorized_top_k/top_5_categorical_accuracy: 0.0000e+00 - factorized_top_k/top_10_categorical_accuracy: 0.0000e+00 - factorized_top_k/top_50_categorical_accuracy: 0.0000e+00 - factorized_top_k/top_100_categorical_accuracy: 0.0000e+00 - loss: 13612.3069 - regularization_loss: 0.0000e+00 - total_loss: 13612.3069 - val_factorized_top_k/top_1_categorical_accuracy: 2.5000e-04 - val_factorized_top_k/top_5_categorical_accuracy: 0.0043 - val_factorized_top_k/top_10_categorical_accuracy: 0.0127 - val_factorized_top_k/top_50_categorical_accuracy: 0.1024 - val_factorized_top_k/top_100_categorical_accuracy: 0.2116 - val_loss: 28213.1055 - val_regularization_loss: 0.0000e+00 - val_total_loss: 28213.1055
# Epoch 66/300
# 40/40 [==============================] - 6s 89ms/step - factorized_top_k/top_1_categorical_accuracy: 0.0000e+00 - factorized_top_k/top_5_categorical_accuracy: 0.0000e+00 - factorized_top_k/top_10_categorical_accuracy: 0.0000e+00 - factorized_top_k/top_50_categorical_accuracy: 0.0000e+00 - factorized_top_k/top_100_categorical_accuracy: 0.0000e+00 - loss: 13606.8718 - regularization_loss: 0.0000e+00 - total_loss: 13606.8718
# Epoch 67/300
# 40/40 [==============================] - 7s 92ms/step - factorized_top_k/top_1_categorical_accuracy: 0.0000e+00 - factorized_top_k/top_5_categorical_accuracy: 0.0000e+00 - factorized_top_k/top_10_categorical_accuracy: 0.0000e+00 - factorized_top_k/top_50_categorical_accuracy: 0.0000e+00 - factorized_top_k/top_100_categorical_accuracy: 0.0000e+00 - loss: 13603.5144 - regularization_loss: 0.0000e+00 - total_loss: 13603.5144
# Epoch 68/300
# 40/40 [==============================] - 6s 91ms/step - factorized_top_k/top_1_categorical_accuracy: 0.0000e+00 - factorized_top_k/top_5_categorical_accuracy: 0.0000e+00 - factorized_top_k/top_10_categorical_accuracy: 0.0000e+00 - factorized_top_k/top_50_categorical_accuracy: 0.0000e+00 - factorized_top_k/top_100_categorical_accuracy: 0.0000e+00 - loss: 13598.0117 - regularization_loss: 0.0000e+00 - total_loss: 13598.0117
# Epoch 69/300
# 40/40 [==============================] - 6s 89ms/step - factorized_top_k/top_1_categorical_accuracy: 0.0000e+00 - factorized_top_k/top_5_categorical_accuracy: 0.0000e+00 - factorized_top_k/top_10_categorical_accuracy: 0.0000e+00 - factorized_top_k/top_50_categorical_accuracy: 0.0000e+00 - factorized_top_k/top_100_categorical_accuracy: 0.0000e+00 - loss: 13593.3566 - regularization_loss: 0.0000e+00 - total_loss: 13593.3566
# Epoch 70/300
# 40/40 [==============================] - 11s 214ms/step - factorized_top_k/top_1_categorical_accuracy: 0.0000e+00 - factorized_top_k/top_5_categorical_accuracy: 0.0000e+00 - factorized_top_k/top_10_categorical_accuracy: 0.0000e+00 - factorized_top_k/top_50_categorical_accuracy: 0.0000e+00 - factorized_top_k/top_100_categorical_accuracy: 0.0000e+00 - loss: 13589.5472 - regularization_loss: 0.0000e+00 - total_loss: 13589.5472 - val_factorized_top_k/top_1_categorical_accuracy: 2.0000e-04 - val_factorized_top_k/top_5_categorical_accuracy: 0.0054 - val_factorized_top_k/top_10_categorical_accuracy: 0.0136 - val_factorized_top_k/top_50_categorical_accuracy: 0.1070 - val_factorized_top_k/top_100_categorical_accuracy: 0.2224 - val_loss: 28224.2871 - val_regularization_loss: 0.0000e+00 - val_total_loss: 28224.2871
# Epoch 71/300
# 40/40 [==============================] - 6s 91ms/step - factorized_top_k/top_1_categorical_accuracy: 0.0000e+00 - factorized_top_k/top_5_categorical_accuracy: 0.0000e+00 - factorized_top_k/top_10_categorical_accuracy: 0.0000e+00 - factorized_top_k/top_50_categorical_accuracy: 0.0000e+00 - factorized_top_k/top_100_categorical_accuracy: 0.0000e+00 - loss: 13586.3487 - regularization_loss: 0.0000e+00 - total_loss: 13586.3487
# Epoch 72/300
# 40/40 [==============================] - 6s 92ms/step - factorized_top_k/top_1_categorical_accuracy: 0.0000e+00 - factorized_top_k/top_5_categorical_accuracy: 0.0000e+00 - factorized_top_k/top_10_categorical_accuracy: 0.0000e+00 - factorized_top_k/top_50_categorical_accuracy: 0.0000e+00 - factorized_top_k/top_100_categorical_accuracy: 0.0000e+00 - loss: 13583.1512 - regularization_loss: 0.0000e+00 - total_loss: 13583.1512
# Epoch 73/300
# 40/40 [==============================] - 6s 92ms/step - factorized_top_k/top_1_categorical_accuracy: 0.0000e+00 - factorized_top_k/top_5_categorical_accuracy: 0.0000e+00 - factorized_top_k/top_10_categorical_accuracy: 0.0000e+00 - factorized_top_k/top_50_categorical_accuracy: 0.0000e+00 - factorized_top_k/top_100_categorical_accuracy: 0.0000e+00 - loss: 13579.6447 - regularization_loss: 0.0000e+00 - total_loss: 13579.6447
# Epoch 74/300
# 40/40 [==============================] - 6s 90ms/step - factorized_top_k/top_1_categorical_accuracy: 0.0000e+00 - factorized_top_k/top_5_categorical_accuracy: 0.0000e+00 - factorized_top_k/top_10_categorical_accuracy: 0.0000e+00 - factorized_top_k/top_50_categorical_accuracy: 0.0000e+00 - factorized_top_k/top_100_categorical_accuracy: 0.0000e+00 - loss: 13577.2431 - regularization_loss: 0.0000e+00 - total_loss: 13577.2431
# Epoch 75/300
# 40/40 [==============================] - 12s 227ms/step - factorized_top_k/top_1_categorical_accuracy: 0.0000e+00 - factorized_top_k/top_5_categorical_accuracy: 0.0000e+00 - factorized_top_k/top_10_categorical_accuracy: 0.0000e+00 - factorized_top_k/top_50_categorical_accuracy: 0.0000e+00 - factorized_top_k/top_100_categorical_accuracy: 0.0000e+00 - loss: 13572.7163 - regularization_loss: 0.0000e+00 - total_loss: 13572.7163 - val_factorized_top_k/top_1_categorical_accuracy: 4.0000e-04 - val_factorized_top_k/top_5_categorical_accuracy: 0.0049 - val_factorized_top_k/top_10_categorical_accuracy: 0.0129 - val_factorized_top_k/top_50_categorical_accuracy: 0.1055 - val_factorized_top_k/top_100_categorical_accuracy: 0.2192 - val_loss: 28227.8242 - val_regularization_loss: 0.0000e+00 - val_total_loss: 28227.8242
# Epoch 76/300
# 40/40 [==============================] - 6s 92ms/step - factorized_top_k/top_1_categorical_accuracy: 0.0000e+00 - factorized_top_k/top_5_categorical_accuracy: 0.0000e+00 - factorized_top_k/top_10_categorical_accuracy: 0.0000e+00 - factorized_top_k/top_50_categorical_accuracy: 0.0000e+00 - factorized_top_k/top_100_categorical_accuracy: 0.0000e+00 - loss: 13568.7721 - regularization_loss: 0.0000e+00 - total_loss: 13568.7721
# Epoch 77/300
# 40/40 [==============================] - 7s 106ms/step - factorized_top_k/top_1_categorical_accuracy: 0.0000e+00 - factorized_top_k/top_5_categorical_accuracy: 0.0000e+00 - factorized_top_k/top_10_categorical_accuracy: 0.0000e+00 - factorized_top_k/top_50_categorical_accuracy: 0.0000e+00 - factorized_top_k/top_100_categorical_accuracy: 0.0000e+00 - loss: 13566.7647 - regularization_loss: 0.0000e+00 - total_loss: 13566.7647
# Epoch 78/300
# 40/40 [==============================] - 8s 123ms/step - factorized_top_k/top_1_categorical_accuracy: 0.0000e+00 - factorized_top_k/top_5_categorical_accuracy: 0.0000e+00 - factorized_top_k/top_10_categorical_accuracy: 0.0000e+00 - factorized_top_k/top_50_categorical_accuracy: 0.0000e+00 - factorized_top_k/top_100_categorical_accuracy: 0.0000e+00 - loss: 13563.1376 - regularization_loss: 0.0000e+00 - total_loss: 13563.1376
# Epoch 79/300
# 40/40 [==============================] - 7s 94ms/step - factorized_top_k/top_1_categorical_accuracy: 0.0000e+00 - factorized_top_k/top_5_categorical_accuracy: 0.0000e+00 - factorized_top_k/top_10_categorical_accuracy: 0.0000e+00 - factorized_top_k/top_50_categorical_accuracy: 0.0000e+00 - factorized_top_k/top_100_categorical_accuracy: 0.0000e+00 - loss: 13560.6796 - regularization_loss: 0.0000e+00 - total_loss: 13560.6796
# Epoch 80/300
# 40/40 [==============================] - 15s 281ms/step - factorized_top_k/top_1_categorical_accuracy: 0.0000e+00 - factorized_top_k/top_5_categorical_accuracy: 0.0000e+00 - factorized_top_k/top_10_categorical_accuracy: 0.0000e+00 - factorized_top_k/top_50_categorical_accuracy: 0.0000e+00 - factorized_top_k/top_100_categorical_accuracy: 0.0000e+00 - loss: 13558.6168 - regularization_loss: 0.0000e+00 - total_loss: 13558.6168 - val_factorized_top_k/top_1_categorical_accuracy: 3.0000e-04 - val_factorized_top_k/top_5_categorical_accuracy: 0.0044 - val_factorized_top_k/top_10_categorical_accuracy: 0.0117 - val_factorized_top_k/top_50_categorical_accuracy: 0.1043 - val_factorized_top_k/top_100_categorical_accuracy: 0.2192 - val_loss: 28241.7695 - val_regularization_loss: 0.0000e+00 - val_total_loss: 28241.7695
# Epoch 81/300
# 40/40 [==============================] - 6s 90ms/step - factorized_top_k/top_1_categorical_accuracy: 0.0000e+00 - factorized_top_k/top_5_categorical_accuracy: 0.0000e+00 - factorized_top_k/top_10_categorical_accuracy: 0.0000e+00 - factorized_top_k/top_50_categorical_accuracy: 0.0000e+00 - factorized_top_k/top_100_categorical_accuracy: 0.0000e+00 - loss: 13555.3114 - regularization_loss: 0.0000e+00 - total_loss: 13555.3114
# Epoch 82/300
# 40/40 [==============================] - 6s 92ms/step - factorized_top_k/top_1_categorical_accuracy: 0.0000e+00 - factorized_top_k/top_5_categorical_accuracy: 0.0000e+00 - factorized_top_k/top_10_categorical_accuracy: 0.0000e+00 - factorized_top_k/top_50_categorical_accuracy: 0.0000e+00 - factorized_top_k/top_100_categorical_accuracy: 0.0000e+00 - loss: 13551.8908 - regularization_loss: 0.0000e+00 - total_loss: 13551.8908
# Epoch 83/300
# 40/40 [==============================] - 6s 92ms/step - factorized_top_k/top_1_categorical_accuracy: 0.0000e+00 - factorized_top_k/top_5_categorical_accuracy: 0.0000e+00 - factorized_top_k/top_10_categorical_accuracy: 0.0000e+00 - factorized_top_k/top_50_categorical_accuracy: 0.0000e+00 - factorized_top_k/top_100_categorical_accuracy: 0.0000e+00 - loss: 13548.4211 - regularization_loss: 0.0000e+00 - total_loss: 13548.4211
# Epoch 84/300
# 40/40 [==============================] - 6s 92ms/step - factorized_top_k/top_1_categorical_accuracy: 0.0000e+00 - factorized_top_k/top_5_categorical_accuracy: 0.0000e+00 - factorized_top_k/top_10_categorical_accuracy: 0.0000e+00 - factorized_top_k/top_50_categorical_accuracy: 0.0000e+00 - factorized_top_k/top_100_categorical_accuracy: 0.0000e+00 - loss: 13547.0114 - regularization_loss: 0.0000e+00 - total_loss: 13547.0114
# Epoch 85/300
# 40/40 [==============================] - 11s 217ms/step - factorized_top_k/top_1_categorical_accuracy: 0.0000e+00 - factorized_top_k/top_5_categorical_accuracy: 0.0000e+00 - factorized_top_k/top_10_categorical_accuracy: 0.0000e+00 - factorized_top_k/top_50_categorical_accuracy: 0.0000e+00 - factorized_top_k/top_100_categorical_accuracy: 0.0000e+00 - loss: 13543.1949 - regularization_loss: 0.0000e+00 - total_loss: 13543.1949 - val_factorized_top_k/top_1_categorical_accuracy: 3.5000e-04 - val_factorized_top_k/top_5_categorical_accuracy: 0.0048 - val_factorized_top_k/top_10_categorical_accuracy: 0.0119 - val_factorized_top_k/top_50_categorical_accuracy: 0.1081 - val_factorized_top_k/top_100_categorical_accuracy: 0.2246 - val_loss: 28262.4922 - val_regularization_loss: 0.0000e+00 - val_total_loss: 28262.4922
# Epoch 86/300
# 40/40 [==============================] - 6s 91ms/step - factorized_top_k/top_1_categorical_accuracy: 0.0000e+00 - factorized_top_k/top_5_categorical_accuracy: 0.0000e+00 - factorized_top_k/top_10_categorical_accuracy: 0.0000e+00 - factorized_top_k/top_50_categorical_accuracy: 0.0000e+00 - factorized_top_k/top_100_categorical_accuracy: 0.0000e+00 - loss: 13538.9130 - regularization_loss: 0.0000e+00 - total_loss: 13538.9130
# Epoch 87/300
# 40/40 [==============================] - 6s 90ms/step - factorized_top_k/top_1_categorical_accuracy: 0.0000e+00 - factorized_top_k/top_5_categorical_accuracy: 0.0000e+00 - factorized_top_k/top_10_categorical_accuracy: 0.0000e+00 - factorized_top_k/top_50_categorical_accuracy: 0.0000e+00 - factorized_top_k/top_100_categorical_accuracy: 0.0000e+00 - loss: 13536.5941 - regularization_loss: 0.0000e+00 - total_loss: 13536.5941
# Epoch 88/300
# 40/40 [==============================] - 6s 91ms/step - factorized_top_k/top_1_categorical_accuracy: 0.0000e+00 - factorized_top_k/top_5_categorical_accuracy: 0.0000e+00 - factorized_top_k/top_10_categorical_accuracy: 0.0000e+00 - factorized_top_k/top_50_categorical_accuracy: 0.0000e+00 - factorized_top_k/top_100_categorical_accuracy: 0.0000e+00 - loss: 13534.5231 - regularization_loss: 0.0000e+00 - total_loss: 13534.5231
# Epoch 89/300
# 40/40 [==============================] - 7s 97ms/step - factorized_top_k/top_1_categorical_accuracy: 0.0000e+00 - factorized_top_k/top_5_categorical_accuracy: 0.0000e+00 - factorized_top_k/top_10_categorical_accuracy: 0.0000e+00 - factorized_top_k/top_50_categorical_accuracy: 0.0000e+00 - factorized_top_k/top_100_categorical_accuracy: 0.0000e+00 - loss: 13532.1236 - regularization_loss: 0.0000e+00 - total_loss: 13532.1236
# Epoch 90/300
# 40/40 [==============================] - 13s 253ms/step - factorized_top_k/top_1_categorical_accuracy: 0.0000e+00 - factorized_top_k/top_5_categorical_accuracy: 0.0000e+00 - factorized_top_k/top_10_categorical_accuracy: 0.0000e+00 - factorized_top_k/top_50_categorical_accuracy: 0.0000e+00 - factorized_top_k/top_100_categorical_accuracy: 0.0000e+00 - loss: 13528.6970 - regularization_loss: 0.0000e+00 - total_loss: 13528.6970 - val_factorized_top_k/top_1_categorical_accuracy: 3.5000e-04 - val_factorized_top_k/top_5_categorical_accuracy: 0.0046 - val_factorized_top_k/top_10_categorical_accuracy: 0.0122 - val_factorized_top_k/top_50_categorical_accuracy: 0.1081 - val_factorized_top_k/top_100_categorical_accuracy: 0.2224 - val_loss: 28274.3320 - val_regularization_loss: 0.0000e+00 - val_total_loss: 28274.3320
# Epoch 91/300
# 40/40 [==============================] - 6s 91ms/step - factorized_top_k/top_1_categorical_accuracy: 0.0000e+00 - factorized_top_k/top_5_categorical_accuracy: 0.0000e+00 - factorized_top_k/top_10_categorical_accuracy: 0.0000e+00 - factorized_top_k/top_50_categorical_accuracy: 0.0000e+00 - factorized_top_k/top_100_categorical_accuracy: 0.0000e+00 - loss: 13525.1692 - regularization_loss: 0.0000e+00 - total_loss: 13525.1692
# Epoch 92/300
# 40/40 [==============================] - 7s 90ms/step - factorized_top_k/top_1_categorical_accuracy: 0.0000e+00 - factorized_top_k/top_5_categorical_accuracy: 0.0000e+00 - factorized_top_k/top_10_categorical_accuracy: 0.0000e+00 - factorized_top_k/top_50_categorical_accuracy: 0.0000e+00 - factorized_top_k/top_100_categorical_accuracy: 0.0000e+00 - loss: 13521.3768 - regularization_loss: 0.0000e+00 - total_loss: 13521.3768
# Epoch 93/300
# 40/40 [==============================] - 6s 91ms/step - factorized_top_k/top_1_categorical_accuracy: 0.0000e+00 - factorized_top_k/top_5_categorical_accuracy: 0.0000e+00 - factorized_top_k/top_10_categorical_accuracy: 0.0000e+00 - factorized_top_k/top_50_categorical_accuracy: 0.0000e+00 - factorized_top_k/top_100_categorical_accuracy: 0.0000e+00 - loss: 13519.1914 - regularization_loss: 0.0000e+00 - total_loss: 13519.1914
# Epoch 94/300
# ...
# Epoch 271/300
# 40/40 [==============================] - 7s 96ms/step - factorized_top_k/top_1_categorical_accuracy: 0.0000e+00 - factorized_top_k/top_5_categorical_accuracy: 0.0000e+00 - factorized_top_k/top_10_categorical_accuracy: 0.0000e+00 - factorized_top_k/top_50_categorical_accuracy: 0.0000e+00 - factorized_top_k/top_100_categorical_accuracy: 0.0000e+00 - loss: 13146.7495 - regularization_loss: 0.0000e+00 - total_loss: 13146.7495
# Epoch 272/300
# 40/40 [==============================] - 6s 96ms/step - factorized_top_k/top_1_categorical_accuracy: 0.0000e+00 - factorized_top_k/top_5_categorical_accuracy: 0.0000e+00 - factorized_top_k/top_10_categorical_accuracy: 0.0000e+00 - factorized_top_k/top_50_categorical_accuracy: 0.0000e+00 - factorized_top_k/top_100_categorical_accuracy: 0.0000e+00 - loss: 13146.0894 - regularization_loss: 0.0000e+00 - total_loss: 13146.0894
# Epoch 273/300
# 40/40 [==============================] - 10s 185ms/step - factorized_top_k/top_1_categorical_accuracy: 0.0000e+00 - factorized_top_k/top_5_categorical_accuracy: 0.0000e+00 - factorized_top_k/top_10_categorical_accuracy: 0.0000e+00 - factorized_top_k/top_50_categorical_accuracy: 0.0000e+00 - factorized_top_k/top_100_categorical_accuracy: 0.0000e+00 - loss: 13143.2077 - regularization_loss: 0.0000e+00 - total_loss: 13143.2077
# Epoch 274/300
# 40/40 [==============================] - 7s 99ms/step - factorized_top_k/top_1_categorical_accuracy: 0.0000e+00 - factorized_top_k/top_5_categorical_accuracy: 0.0000e+00 - factorized_top_k/top_10_categorical_accuracy: 0.0000e+00 - factorized_top_k/top_50_categorical_accuracy: 0.0000e+00 - factorized_top_k/top_100_categorical_accuracy: 0.0000e+00 - loss: 13144.9371 - regularization_loss: 0.0000e+00 - total_loss: 13144.9371
# Epoch 275/300
# 40/40 [==============================] - 12s 239ms/step - factorized_top_k/top_1_categorical_accuracy: 0.0000e+00 - factorized_top_k/top_5_categorical_accuracy: 0.0000e+00 - factorized_top_k/top_10_categorical_accuracy: 0.0000e+00 - factorized_top_k/top_50_categorical_accuracy: 0.0000e+00 - factorized_top_k/top_100_categorical_accuracy: 0.0000e+00 - loss: 13141.5598 - regularization_loss: 0.0000e+00 - total_loss: 13141.5598 - val_factorized_top_k/top_1_categorical_accuracy: 0.0000e+00 - val_factorized_top_k/top_5_categorical_accuracy: 0.0023 - val_factorized_top_k/top_10_categorical_accuracy: 0.0074 - val_factorized_top_k/top_50_categorical_accuracy: 0.1003 - val_factorized_top_k/top_100_categorical_accuracy: 0.2335 - val_loss: 29214.4648 - val_regularization_loss: 0.0000e+00 - val_total_loss: 29214.4648
# Epoch 276/300
# 40/40 [==============================] - 7s 99ms/step - factorized_top_k/top_1_categorical_accuracy: 0.0000e+00 - factorized_top_k/top_5_categorical_accuracy: 0.0000e+00 - factorized_top_k/top_10_categorical_accuracy: 0.0000e+00 - factorized_top_k/top_50_categorical_accuracy: 0.0000e+00 - factorized_top_k/top_100_categorical_accuracy: 0.0000e+00 - loss: 13140.8281 - regularization_loss: 0.0000e+00 - total_loss: 13140.8281
# Epoch 277/300
# 40/40 [==============================] - 7s 96ms/step - factorized_top_k/top_1_categorical_accuracy: 0.0000e+00 - factorized_top_k/top_5_categorical_accuracy: 0.0000e+00 - factorized_top_k/top_10_categorical_accuracy: 0.0000e+00 - factorized_top_k/top_50_categorical_accuracy: 0.0000e+00 - factorized_top_k/top_100_categorical_accuracy: 0.0000e+00 - loss: 13140.1737 - regularization_loss: 0.0000e+00 - total_loss: 13140.1737
# Epoch 278/300
# 40/40 [==============================] - 7s 98ms/step - factorized_top_k/top_1_categorical_accuracy: 0.0000e+00 - factorized_top_k/top_5_categorical_accuracy: 0.0000e+00 - factorized_top_k/top_10_categorical_accuracy: 0.0000e+00 - factorized_top_k/top_50_categorical_accuracy: 0.0000e+00 - factorized_top_k/top_100_categorical_accuracy: 0.0000e+00 - loss: 13138.7979 - regularization_loss: 0.0000e+00 - total_loss: 13138.7979
# Epoch 279/300
# 40/40 [==============================] - 7s 104ms/step - factorized_top_k/top_1_categorical_accuracy: 0.0000e+00 - factorized_top_k/top_5_categorical_accuracy: 0.0000e+00 - factorized_top_k/top_10_categorical_accuracy: 0.0000e+00 - factorized_top_k/top_50_categorical_accuracy: 0.0000e+00 - factorized_top_k/top_100_categorical_accuracy: 0.0000e+00 - loss: 13138.4225 - regularization_loss: 0.0000e+00 - total_loss: 13138.4225
# Epoch 280/300
# 40/40 [==============================] - 14s 291ms/step - factorized_top_k/top_1_categorical_accuracy: 0.0000e+00 - factorized_top_k/top_5_categorical_accuracy: 0.0000e+00 - factorized_top_k/top_10_categorical_accuracy: 0.0000e+00 - factorized_top_k/top_50_categorical_accuracy: 0.0000e+00 - factorized_top_k/top_100_categorical_accuracy: 0.0000e+00 - loss: 13135.3977 - regularization_loss: 0.0000e+00 - total_loss: 13135.3977 - val_factorized_top_k/top_1_categorical_accuracy: 0.0000e+00 - val_factorized_top_k/top_5_categorical_accuracy: 0.0021 - val_factorized_top_k/top_10_categorical_accuracy: 0.0069 - val_factorized_top_k/top_50_categorical_accuracy: 0.1001 - val_factorized_top_k/top_100_categorical_accuracy: 0.2285 - val_loss: 29238.3086 - val_regularization_loss: 0.0000e+00 - val_total_loss: 29238.3086
# Epoch 281/300
# 40/40 [==============================] - 7s 99ms/step - factorized_top_k/top_1_categorical_accuracy: 0.0000e+00 - factorized_top_k/top_5_categorical_accuracy: 0.0000e+00 - factorized_top_k/top_10_categorical_accuracy: 0.0000e+00 - factorized_top_k/top_50_categorical_accuracy: 0.0000e+00 - factorized_top_k/top_100_categorical_accuracy: 0.0000e+00 - loss: 13134.0296 - regularization_loss: 0.0000e+00 - total_loss: 13134.0296
# Epoch 282/300
# 40/40 [==============================] - 7s 98ms/step - factorized_top_k/top_1_categorical_accuracy: 0.0000e+00 - factorized_top_k/top_5_categorical_accuracy: 0.0000e+00 - factorized_top_k/top_10_categorical_accuracy: 0.0000e+00 - factorized_top_k/top_50_categorical_accuracy: 0.0000e+00 - factorized_top_k/top_100_categorical_accuracy: 0.0000e+00 - loss: 13133.9956 - regularization_loss: 0.0000e+00 - total_loss: 13133.9956
# Epoch 283/300
# 40/40 [==============================] - 7s 98ms/step - factorized_top_k/top_1_categorical_accuracy: 0.0000e+00 - factorized_top_k/top_5_categorical_accuracy: 0.0000e+00 - factorized_top_k/top_10_categorical_accuracy: 0.0000e+00 - factorized_top_k/top_50_categorical_accuracy: 0.0000e+00 - factorized_top_k/top_100_categorical_accuracy: 0.0000e+00 - loss: 13133.8443 - regularization_loss: 0.0000e+00 - total_loss: 13133.8443
# Epoch 284/300
# 40/40 [==============================] - 7s 100ms/step - factorized_top_k/top_1_categorical_accuracy: 0.0000e+00 - factorized_top_k/top_5_categorical_accuracy: 0.0000e+00 - factorized_top_k/top_10_categorical_accuracy: 0.0000e+00 - factorized_top_k/top_50_categorical_accuracy: 0.0000e+00 - factorized_top_k/top_100_categorical_accuracy: 0.0000e+00 - loss: 13131.3746 - regularization_loss: 0.0000e+00 - total_loss: 13131.3746
# Epoch 285/300
# 40/40 [==============================] - 12s 237ms/step - factorized_top_k/top_1_categorical_accuracy: 0.0000e+00 - factorized_top_k/top_5_categorical_accuracy: 0.0000e+00 - factorized_top_k/top_10_categorical_accuracy: 0.0000e+00 - factorized_top_k/top_50_categorical_accuracy: 0.0000e+00 - factorized_top_k/top_100_categorical_accuracy: 0.0000e+00 - loss: 13130.8998 - regularization_loss: 0.0000e+00 - total_loss: 13130.8998 - val_factorized_top_k/top_1_categorical_accuracy: 5.0000e-05 - val_factorized_top_k/top_5_categorical_accuracy: 0.0019 - val_factorized_top_k/top_10_categorical_accuracy: 0.0069 - val_factorized_top_k/top_50_categorical_accuracy: 0.0988 - val_factorized_top_k/top_100_categorical_accuracy: 0.2288 - val_loss: 29258.2676 - val_regularization_loss: 0.0000e+00 - val_total_loss: 29258.2676
# Epoch 286/300
# 40/40 [==============================] - 7s 100ms/step - factorized_top_k/top_1_categorical_accuracy: 0.0000e+00 - factorized_top_k/top_5_categorical_accuracy: 0.0000e+00 - factorized_top_k/top_10_categorical_accuracy: 0.0000e+00 - factorized_top_k/top_50_categorical_accuracy: 0.0000e+00 - factorized_top_k/top_100_categorical_accuracy: 0.0000e+00 - loss: 13129.9998 - regularization_loss: 0.0000e+00 - total_loss: 13129.9998
# Epoch 287/300
# 40/40 [==============================] - 7s 102ms/step - factorized_top_k/top_1_categorical_accuracy: 0.0000e+00 - factorized_top_k/top_5_categorical_accuracy: 0.0000e+00 - factorized_top_k/top_10_categorical_accuracy: 0.0000e+00 - factorized_top_k/top_50_categorical_accuracy: 0.0000e+00 - factorized_top_k/top_100_categorical_accuracy: 0.0000e+00 - loss: 13128.3821 - regularization_loss: 0.0000e+00 - total_loss: 13128.3821
# Epoch 288/300
# 40/40 [==============================] - 7s 100ms/step - factorized_top_k/top_1_categorical_accuracy: 0.0000e+00 - factorized_top_k/top_5_categorical_accuracy: 0.0000e+00 - factorized_top_k/top_10_categorical_accuracy: 0.0000e+00 - factorized_top_k/top_50_categorical_accuracy: 0.0000e+00 - factorized_top_k/top_100_categorical_accuracy: 0.0000e+00 - loss: 13127.6671 - regularization_loss: 0.0000e+00 - total_loss: 13127.6671
# Epoch 289/300
# 40/40 [==============================] - 7s 100ms/step - factorized_top_k/top_1_categorical_accuracy: 0.0000e+00 - factorized_top_k/top_5_categorical_accuracy: 0.0000e+00 - factorized_top_k/top_10_categorical_accuracy: 0.0000e+00 - factorized_top_k/top_50_categorical_accuracy: 0.0000e+00 - factorized_top_k/top_100_categorical_accuracy: 0.0000e+00 - loss: 13126.5455 - regularization_loss: 0.0000e+00 - total_loss: 13126.5455
# Epoch 290/300
# 40/40 [==============================] - 13s 250ms/step - factorized_top_k/top_1_categorical_accuracy: 0.0000e+00 - factorized_top_k/top_5_categorical_accuracy: 0.0000e+00 - factorized_top_k/top_10_categorical_accuracy: 0.0000e+00 - factorized_top_k/top_50_categorical_accuracy: 0.0000e+00 - factorized_top_k/top_100_categorical_accuracy: 0.0000e+00 - loss: 13125.4320 - regularization_loss: 0.0000e+00 - total_loss: 13125.4320 - val_factorized_top_k/top_1_categorical_accuracy: 1.0000e-04 - val_factorized_top_k/top_5_categorical_accuracy: 0.0020 - val_factorized_top_k/top_10_categorical_accuracy: 0.0073 - val_factorized_top_k/top_50_categorical_accuracy: 0.1014 - val_factorized_top_k/top_100_categorical_accuracy: 0.2345 - val_loss: 29274.0801 - val_regularization_loss: 0.0000e+00 - val_total_loss: 29274.0801
# Epoch 291/300
# 40/40 [==============================] - 7s 97ms/step - factorized_top_k/top_1_categorical_accuracy: 0.0000e+00 - factorized_top_k/top_5_categorical_accuracy: 0.0000e+00 - factorized_top_k/top_10_categorical_accuracy: 0.0000e+00 - factorized_top_k/top_50_categorical_accuracy: 0.0000e+00 - factorized_top_k/top_100_categorical_accuracy: 0.0000e+00 - loss: 13124.4221 - regularization_loss: 0.0000e+00 - total_loss: 13124.4221
# Epoch 292/300
# 40/40 [==============================] - 7s 98ms/step - factorized_top_k/top_1_categorical_accuracy: 0.0000e+00 - factorized_top_k/top_5_categorical_accuracy: 0.0000e+00 - factorized_top_k/top_10_categorical_accuracy: 0.0000e+00 - factorized_top_k/top_50_categorical_accuracy: 0.0000e+00 - factorized_top_k/top_100_categorical_accuracy: 0.0000e+00 - loss: 13123.4927 - regularization_loss: 0.0000e+00 - total_loss: 13123.4927
# Epoch 293/300
# 40/40 [==============================] - 7s 100ms/step - factorized_top_k/top_1_categorical_accuracy: 0.0000e+00 - factorized_top_k/top_5_categorical_accuracy: 0.0000e+00 - factorized_top_k/top_10_categorical_accuracy: 0.0000e+00 - factorized_top_k/top_50_categorical_accuracy: 0.0000e+00 - factorized_top_k/top_100_categorical_accuracy: 0.0000e+00 - loss: 13121.1492 - regularization_loss: 0.0000e+00 - total_loss: 13121.1492
# Epoch 294/300
# 40/40 [==============================] - 7s 97ms/step - factorized_top_k/top_1_categorical_accuracy: 0.0000e+00 - factorized_top_k/top_5_categorical_accuracy: 0.0000e+00 - factorized_top_k/top_10_categorical_accuracy: 0.0000e+00 - factorized_top_k/top_50_categorical_accuracy: 0.0000e+00 - factorized_top_k/top_100_categorical_accuracy: 0.0000e+00 - loss: 13120.2870 - regularization_loss: 0.0000e+00 - total_loss: 13120.2870
# Epoch 295/300
# 40/40 [==============================] - 12s 235ms/step - factorized_top_k/top_1_categorical_accuracy: 0.0000e+00 - factorized_top_k/top_5_categorical_accuracy: 0.0000e+00 - factorized_top_k/top_10_categorical_accuracy: 0.0000e+00 - factorized_top_k/top_50_categorical_accuracy: 0.0000e+00 - factorized_top_k/top_100_categorical_accuracy: 0.0000e+00 - loss: 13119.1300 - regularization_loss: 0.0000e+00 - total_loss: 13119.1300 - val_factorized_top_k/top_1_categorical_accuracy: 5.0000e-05 - val_factorized_top_k/top_5_categorical_accuracy: 0.0017 - val_factorized_top_k/top_10_categorical_accuracy: 0.0065 - val_factorized_top_k/top_50_categorical_accuracy: 0.1017 - val_factorized_top_k/top_100_categorical_accuracy: 0.2323 - val_loss: 29300.8730 - val_regularization_loss: 0.0000e+00 - val_total_loss: 29300.8730
# Epoch 296/300
# 40/40 [==============================] - 7s 96ms/step - factorized_top_k/top_1_categorical_accuracy: 0.0000e+00 - factorized_top_k/top_5_categorical_accuracy: 0.0000e+00 - factorized_top_k/top_10_categorical_accuracy: 0.0000e+00 - factorized_top_k/top_50_categorical_accuracy: 0.0000e+00 - factorized_top_k/top_100_categorical_accuracy: 0.0000e+00 - loss: 13119.8616 - regularization_loss: 0.0000e+00 - total_loss: 13119.8616
# Epoch 297/300
# 40/40 [==============================] - 7s 97ms/step - factorized_top_k/top_1_categorical_accuracy: 0.0000e+00 - factorized_top_k/top_5_categorical_accuracy: 0.0000e+00 - factorized_top_k/top_10_categorical_accuracy: 0.0000e+00 - factorized_top_k/top_50_categorical_accuracy: 0.0000e+00 - factorized_top_k/top_100_categorical_accuracy: 0.0000e+00 - loss: 13117.6907 - regularization_loss: 0.0000e+00 - total_loss: 13117.6907
# Epoch 298/300
# 40/40 [==============================] - 7s 98ms/step - factorized_top_k/top_1_categorical_accuracy: 0.0000e+00 - factorized_top_k/top_5_categorical_accuracy: 0.0000e+00 - factorized_top_k/top_10_categorical_accuracy: 0.0000e+00 - factorized_top_k/top_50_categorical_accuracy: 0.0000e+00 - factorized_top_k/top_100_categorical_accuracy: 0.0000e+00 - loss: 13117.0166 - regularization_loss: 0.0000e+00 - total_loss: 13117.0166
# Epoch 299/300
# 40/40 [==============================] - 7s 97ms/step - factorized_top_k/top_1_categorical_accuracy: 0.0000e+00 - factorized_top_k/top_5_categorical_accuracy: 0.0000e+00 - factorized_top_k/top_10_categorical_accuracy: 0.0000e+00 - factorized_top_k/top_50_categorical_accuracy: 0.0000e+00 - factorized_top_k/top_100_categorical_accuracy: 0.0000e+00 - loss: 13116.7446 - regularization_loss: 0.0000e+00 - total_loss: 13116.7446
# Epoch 300/300
# 40/40 [==============================] - 11s 222ms/step - factorized_top_k/top_1_categorical_accuracy: 0.0000e+00 - factorized_top_k/top_5_categorical_accuracy: 0.0000e+00 - factorized_top_k/top_10_categorical_accuracy: 0.0000e+00 - factorized_top_k/top_50_categorical_accuracy: 0.0000e+00 - factorized_top_k/top_100_categorical_accuracy: 0.0000e+00 - loss: 13114.6776 - regularization_loss: 0.0000e+00 - total_loss: 13114.6776 - val_factorized_top_k/top_1_categorical_accuracy: 5.0000e-05 - val_factorized_top_k/top_5_categorical_accuracy: 0.0018 - val_factorized_top_k/top_10_categorical_accuracy: 0.0060 - val_factorized_top_k/top_50_categorical_accuracy: 0.1026 - val_factorized_top_k/top_100_categorical_accuracy: 0.2308 - val_loss: 29328.0547 - val_regularization_loss: 0.0000e+00 - val_total_loss: 29328.0547
# Top-100 accuracy: 0.23.

# %%
num_validation_runs = len(two_layer_history.history["val_factorized_top_k/top_100_categorical_accuracy"])
epochs = [(x + 1)* 5 for x in range(num_validation_runs)]

plt.plot(epochs, two_layer_history.history["val_factorized_top_k/top_100_categorical_accuracy"], label="2 layers")
plt.title("Accuracy vs epoch")
plt.xlabel("epoch")
plt.ylabel("Top-100 accuracy");
plt.legend()

# %%
scann_index = tfrs.layers.factorized_top_k.ScaNN(model.query_model, k = 15)
scann_index.index_from_dataset(
  tf.data.Dataset.zip((movies.batch(100), movies.batch(100).map(model.candidate_model)))
)

# %% [markdown]
# Musi byc wykonana metoda __call__ inaczej nie pyknie podczas inferencji.

# %%
_, names = scann_index(tf.constant(['22']))

# %%
tf.saved_model.save(
      scann_index,
      '/content/drive/MyDrive/models/model_ret_pkl',
      options=tf.saved_model.SaveOptions(namespace_whitelist=["Scann"])
  )
# Out:
# WARNING:absl:Found untraced functions such as query_with_exclusions while saving (showing 1 of 1). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: /content/drive/MyDrive/models/model_ret_pkl/assets
# INFO:tensorflow:Assets written to: /content/drive/MyDrive/models/model_ret_pkl/assets

# %%
# m2 = tf.saved_model.load('/content/drive/MyDrive/models/model_ret_pkl')

# %%
# _, names_pred = m2(['22'])

# %%
# names_pred
# Out:
# <tf.Tensor: shape=(1, 15), dtype=string, numpy=
# array([[b'Operation Dumbo Drop (1995)', b'Houseguest (1994)',
#         b'Jingle All the Way (1996)', b'Addams Family Values (1993)',
#         b'Big Green, The (1995)', b'Son in Law (1993)',
#         b'Highlander (1986)', b'Stalker (1979)',
#         b"Pyromaniac's Love Story, A (1995)",
#         b'Great Dictator, The (1940)', b'Tin Men (1987)',
#         b'Quiet Man, The (1952)', b'Die Hard (1988)',
#         b'Full Metal Jacket (1987)', b'Up in Smoke (1978)']], dtype=object)>
